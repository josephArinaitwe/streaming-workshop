# %%
from kafka import KafkaConsumer

server = 'localhost:9092'
topic_name = 'rides'

# %%
import json

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=[server],
    auto_offset_reset='earliest',
    group_id='rides-console',
    value_deserializer=lambda x:json.loads(x)
)

# %%
next(consumer)
# Out:
# ConsumerRecord(topic='rides', partition=0, leader_epoch=1, offset=1, timestamp=1774416517977, timestamp_type=0, key=None, value={'PULocationID': 43, 'DOLocationID': 186, 'trip_distance': 1.68, 'total_amount': 22.15, 'tpep_pickup_datetime': 1761956005000}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=126, serialized_header_size=-1)
